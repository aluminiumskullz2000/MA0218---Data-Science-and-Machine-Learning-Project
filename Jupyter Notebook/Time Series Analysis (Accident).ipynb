# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
import itertools
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
avidata = pd.read_csv('AviationData.csv', parse_dates=['Event.Date'], index_col=['Event.Date'], low_memory=False)

# %%
avidata = avidata[avidata['Country'] == 'United States']
avidata
# Out:
#                   Event.Id Investigation.Type Accident.Number  \
# Event.Date
# 1948-10-24  20001218X45444           Accident      SEA87LA080
# 1962-07-19  20001218X45447           Accident      LAX94LA336
# 1974-08-30  20061025X01555           Accident      NYC07LA005
# 1977-06-19  20001218X45448           Accident      LAX96LA321
# 1979-08-02  20041105X01764           Accident      CHI79FA064
# ...                    ...                ...             ...
# 2021-12-20        2.02E+13           Accident      WPR22LA066
# 2021-12-21        2.02E+13           Accident      GAA22WA054
# 2021-12-22        2.02E+13           Accident      WPR22LA069
# 2021-12-26        2.02E+13           Accident      CEN22FA082
# 2021-12-29        2.02E+13           Accident      ERA22LA097
#
#                    Location        Country   Latitude   Longitude  \
# Event.Date
# 1948-10-24  MOOSE CREEK, ID  United States        NaN         NaN
# 1962-07-19   BRIDGEPORT, CA  United States        NaN         NaN
# 1974-08-30    Saltville, VA  United States  36.922223  -81.878056
# 1977-06-19       EUREKA, CA  United States        NaN         NaN
# 1979-08-02       Canton, OH  United States        NaN         NaN
# ...                     ...            ...        ...         ...
# 2021-12-20      Phoenix, AZ  United States    033483N    0112836W
# 2021-12-21      Auxerre, OF  United States    475047N    0032948W
# 2021-12-22       Auburn, CA  United States        NaN         NaN
# 2021-12-26        Hardy, AR  United States        NaN         NaN
# 2021-12-29     Marathon, FL  United States        NaN         NaN
#
#            Airport.Code Airport.Name Injury.Severity  ... Purpose.of.flight  \
# Event.Date                                            ...
# 1948-10-24          NaN          NaN        Fatal(2)  ...          Personal
# 1962-07-19          NaN          NaN        Fatal(4)  ...          Personal
# 1974-08-30          NaN          NaN        Fatal(3)  ...          Personal
# 1977-06-19          NaN          NaN        Fatal(2)  ...          Personal
# 1979-08-02          NaN          NaN        Fatal(1)  ...          Personal
# ...                 ...          ...             ...  ...               ...
# 2021-12-20          NaN          NaN       Non-Fatal  ...          Business
# 2021-12-21          NaN          NaN           Fatal  ...           Unknown
# 2021-12-22          NaN          NaN       Non-Fatal  ...       Positioning
# 2021-12-26          NaN          NaN           Fatal  ...          Personal
# 2021-12-29          NaN          NaN       Non-Fatal  ...               NaN
#
#                    Air.carrier Total.Fatal.Injuries Total.Serious.Injuries  \
# Event.Date
# 1948-10-24                 NaN                  2.0                    0.0
# 1962-07-19                 NaN                  4.0                    0.0
# 1974-08-30                 NaN                  3.0                    NaN
# 1977-06-19                 NaN                  2.0                    0.0
# 1979-08-02                 NaN                  1.0                    2.0
# ...                        ...                  ...                    ...
# 2021-12-20  RAINBOW RYDERS INC                  0.0                    0.0
# 2021-12-21                 NaN                  1.0                    0.0
# 2021-12-22        Fox Two, LLC                  0.0                    0.0
# 2021-12-26                 NaN                  2.0                    0.0
# 2021-12-29             ExecAir                  0.0                    3.0
#
#            Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Date
# 1948-10-24                  0.0             0.0                UNK
# 1962-07-19                  0.0             0.0                UNK
# 1974-08-30                  NaN             NaN                IMC
# 1977-06-19                  0.0             0.0                IMC
# 1979-08-02                  NaN             0.0                VMC
# ...                         ...             ...                ...
# 2021-12-20                  1.0            15.0                NaN
# 2021-12-21                  0.0             0.0                NaN
# 2021-12-22                  1.0             0.0                NaN
# 2021-12-26                  0.0             0.0                NaN
# 2021-12-29                  0.0             0.0                NaN
#
#            Broad.phase.of.flight   Report.Status Publication.Date
# Event.Date
# 1948-10-24                Cruise  Probable Cause              NaN
# 1962-07-19               Unknown  Probable Cause       19-09-1996
# 1974-08-30                Cruise  Probable Cause       26-02-2007
# 1977-06-19                Cruise  Probable Cause        12/9/2000
# 1979-08-02              Approach  Probable Cause       16-04-1980
# ...                          ...             ...              ...
# 2021-12-20                   NaN             NaN              NaN
# 2021-12-21                   NaN             NaN              NaN
# 2021-12-22                   NaN             NaN              NaN
# 2021-12-26                   NaN             NaN              NaN
# 2021-12-29                   NaN             NaN              NaN
#
# [80998 rows x 30 columns]

# %%
avidata.insert(1, 'Count', 1)
avidata.head()
# Out:
#                   Event.Id  Count Investigation.Type Accident.Number  \
# Event.Date
# 1948-10-24  20001218X45444      1           Accident      SEA87LA080
# 1962-07-19  20001218X45447      1           Accident      LAX94LA336
# 1974-08-30  20061025X01555      1           Accident      NYC07LA005
# 1977-06-19  20001218X45448      1           Accident      LAX96LA321
# 1979-08-02  20041105X01764      1           Accident      CHI79FA064
#
#                    Location        Country   Latitude   Longitude  \
# Event.Date
# 1948-10-24  MOOSE CREEK, ID  United States        NaN         NaN
# 1962-07-19   BRIDGEPORT, CA  United States        NaN         NaN
# 1974-08-30    Saltville, VA  United States  36.922223  -81.878056
# 1977-06-19       EUREKA, CA  United States        NaN         NaN
# 1979-08-02       Canton, OH  United States        NaN         NaN
#
#            Airport.Code Airport.Name  ... Purpose.of.flight Air.carrier  \
# Event.Date                            ...
# 1948-10-24          NaN          NaN  ...          Personal         NaN
# 1962-07-19          NaN          NaN  ...          Personal         NaN
# 1974-08-30          NaN          NaN  ...          Personal         NaN
# 1977-06-19          NaN          NaN  ...          Personal         NaN
# 1979-08-02          NaN          NaN  ...          Personal         NaN
#
#            Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# Event.Date
# 1948-10-24                  2.0                    0.0                  0.0
# 1962-07-19                  4.0                    0.0                  0.0
# 1974-08-30                  3.0                    NaN                  NaN
# 1977-06-19                  2.0                    0.0                  0.0
# 1979-08-02                  1.0                    2.0                  NaN
#
#            Total.Uninjured Weather.Condition  Broad.phase.of.flight  \
# Event.Date
# 1948-10-24             0.0               UNK                 Cruise
# 1962-07-19             0.0               UNK                Unknown
# 1974-08-30             NaN               IMC                 Cruise
# 1977-06-19             0.0               IMC                 Cruise
# 1979-08-02             0.0               VMC               Approach
#
#              Report.Status Publication.Date
# Event.Date
# 1948-10-24  Probable Cause              NaN
# 1962-07-19  Probable Cause       19-09-1996
# 1974-08-30  Probable Cause       26-02-2007
# 1977-06-19  Probable Cause        12/9/2000
# 1979-08-02  Probable Cause       16-04-1980
#
# [5 rows x 31 columns]

# %%
avidata = pd.DataFrame(avidata['Count'])
avidata.head()
# Out:
#             Count
# Event.Date
# 1948-10-24      1
# 1962-07-19      1
# 1974-08-30      1
# 1977-06-19      1
# 1979-08-02      1

# %% [markdown]
# ### Scatterplot of daily data

# %%
aviday = avidata.resample('D').sum()
aviday
# Out:
#             Count
# Event.Date
# 1948-10-24      1
# 1948-10-25      0
# 1948-10-26      0
# 1948-10-27      0
# 1948-10-28      0
# ...           ...
# 2021-12-25      0
# 2021-12-26      1
# 2021-12-27      0
# 2021-12-28      0
# 2021-12-29      1
#
# [26730 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(aviday.index.values, aviday['Count'], color='blue')
ax.set(xlabel="Date", ylabel="Count", title="Aviation Incidents 1948 to 2021")

plt.show()

# %% [markdown]
# ### Scatterplot of monthly data

# %%
avimonth = avidata.resample('M').sum()
avimonth
# Out:
#             Count
# Event.Date
# 1948-10-31      1
# 1948-11-30      0
# 1948-12-31      0
# 1949-01-31      0
# 1949-02-28      0
# ...           ...
# 2021-08-31    116
# 2021-09-30    133
# 2021-10-31    108
# 2021-11-30     83
# 2021-12-31     40
#
# [879 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(avimonth.index.values, avimonth['Count'], color='blue')
ax.set(xlabel="Date", ylabel="Count", title="Aviation Incidents 1948 to 2021")

plt.show()

# %% [markdown]
# ### Scatterplot of yearly data

# %%
aviyear = avidata.resample('Y').sum()
aviyear
# Out:
#             Count
# Event.Date
# 1948-12-31      1
# 1949-12-31      0
# 1950-12-31      0
# 1951-12-31      0
# 1952-12-31      0
# ...           ...
# 2017-12-31   1331
# 2018-12-31   1349
# 2019-12-31   1303
# 2020-12-31   1137
# 2021-12-31   1181
#
# [74 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(aviyear.index.values, aviyear['Count'], color='blue')
ax.set(xlabel="Date", ylabel="Count", title="Aviation Incidents 1948 to 2021")

plt.show()

# %% [markdown]
# Based on scatterplot, data points before the 1980s are lower than 500. For monthly data, it is less than 10. These data will be considered as outliers and removed for analysis.

# %% [markdown]
# ### For analysis of monthly data

# %%
avimonth = avimonth[avimonth['Count'] > 10] 
avimonth
# Out:
#             Count
# Event.Date
# 1982-01-31    206
# 1982-02-28    229
# 1982-03-31    276
# 1982-04-30    302
# 1982-05-31    385
# ...           ...
# 2021-08-31    116
# 2021-09-30    133
# 2021-10-31    108
# 2021-11-30     83
# 2021-12-31     40
#
# [480 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(avimonth.index.values, avimonth['Count'], color='blue')
ax.set(xlabel="Date", ylabel="Count", title="Aviation Incidents 1980s to 2021")

plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(avimonth['Count'], model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ## Time series forecasting with ARIMA
# Applying Autoregressive Integrated Moving Average (ARIMA), a commonly used method for time-series forecasting.
#
# ARIMA models are denoted with the notation ARIMA(p, d, q). These three parameters account for seasonality, trend, and noise in data.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(avimonth,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()
                
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:6355.19195476634
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:5656.057122246695
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:4245.041433062675
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:4069.6880062255004
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:4206.233049957899
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:4035.301715706972
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:4073.3453733452793
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:4065.1028526524333
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:5784.763893133279
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:5254.168184849071
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:4236.510834981465
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:4043.187017993681
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:4208.2284252803065
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:4020.290628889209
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:4062.020122593499
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:4037.9547746333765
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:4723.170946595672
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:4493.114513569414
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:4527.477546033535
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:4117.468402668503
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:4413.068053821218
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:4213.160345650738
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:4265.263848697699
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:4110.06017234764
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:4693.943709956632
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:4483.978289589719
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:4207.578206526629
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:3879.680535333877
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:4189.775202357417
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:3934.2704767625287
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:3985.614844811301
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:3878.993304660109
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:4729.825940305751
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:4497.523920851114
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:4245.0296298826
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:4039.501059041823
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:4200.245299772186
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:4023.6882049888163
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:4047.2670665660476
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:4033.0471978542773
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:4700.681567269818
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:4490.858060278171
# C:\Users\xiayang\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:4211.417839967118
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:3883.9829055590785
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:4197.428482886477
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:3932.559995752877
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:3984.257262470179
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:3882.243540728301
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:4696.0203716736905
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:4495.114502322012
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:4373.194728004048
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:3999.3784914928174
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:4313.122444181408
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:4073.414238805427
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:4101.295419591866
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:3994.2152079820107
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:4681.740600504694
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:4484.900017392585
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:4209.576237967575
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:3880.5852463909496
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:4182.907938636907
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:3936.035030847977
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:3976.963799807055
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:3883.3612651419617

# %% [markdown]
# ## Chosen Model
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:3883.3612651419617 which has the lowest Akaike's Information Criterion (AIC) is chosen.

# %%
mod = sm.tsa.statespace.SARIMAX(avimonth,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0181      0.052     -0.351      0.725      -0.119       0.083
# ma.L1         -0.9112      0.022    -41.930      0.000      -0.954      -0.869
# ar.S.L12      -0.4955      0.040    -12.419      0.000      -0.574      -0.417
# sigma2       365.6544     20.512     17.827      0.000     325.452     405.856
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# Model Diaagnosis shows a nearly normal distribution.

# %% [markdown]
# ## Validating forecasts
# Comparing predicted and real count

# %%
pred = results.get_prediction(start=pd.to_datetime('2005-01-31'), dynamic=False)
pred_ci = pred.conf_int()
ax = avimonth['1982-12-31':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast',
                         alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# ## Producing and visualizing forecasts

# %%
pred_uc = results.get_forecast(steps=200)
pred_ci = pred_uc.conf_int()
ax = avimonth.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.legend()
plt.show()
